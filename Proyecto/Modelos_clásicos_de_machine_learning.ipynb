# %%
# !pip install -q spacy scikit-learn pandas matplotlib seaborn
# !python -m spacy download es_core_news_sm
# Out:
# Collecting es-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.8.0/es_core_news_sm-3.8.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 59.2 MB/s eta 0:00:00
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import pandas as pd
import numpy as np
import spacy
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score
from sklearn.pipeline import Pipeline

# Cargar spaCy español
nlp = spacy.load("es_core_news_sm")

# Cargar dataset
df = pd.read_csv("Corpus_estres.csv")
df['label'] = df['Estres'].map({'si': 1, 'no': 0})

# Preprocesamiento
def preprocess(text):
    doc = nlp(text.lower())
    return " ".join([t.lemma_ for t in doc if t.is_alpha and not t.is_stop])

df['clean_text'] = df['Transcripcion'].apply(preprocess)

#  80/20
X_train, X_test, y_train, y_test = train_test_split(df['clean_text'], df['label'], test_size=0.2, random_state=42)

# %%
# Vectorizadores
vectorizers = {
    "TF-IDF": TfidfVectorizer,
    "Frecuencia": CountVectorizer,
    "Binaria": lambda **kwargs: CountVectorizer(binary=True, **kwargs)
}

# Rangos de n-gramas
ngram_ranges = {
    "unigramas": (1, 1),
    "bigramas": (2, 2),
    "trigramas": (3, 3),
    "uni+bi": (1, 2),
    "uni+tri": (1, 3)
}

# Modelos y grids
models = {
    "NaiveBayes": (MultinomialNB(), {'clf__alpha': [0.1, 1.0, 10]}),
    "SVM": (SVC(), {'clf__C': [0.1, 1, 10], 'clf__kernel': ['linear', 'rbf'], 'clf__gamma': ['scale', 'auto']}),
    "LogisticRegression": (LogisticRegression(max_iter=1000), {'clf__C': [0.1, 1, 10], 'clf__penalty': ['l2']})
}

# %%
from sklearn.metrics import classification_report

results = []

for vec_name, vec_class in vectorizers.items():
    for ngram_name, ngram_range in ngram_ranges.items():
        for model_name, (clf, grid) in models.items():
            print(f"Probando {vec_name} + {ngram_name} + {model_name}")
            vec = vec_class(ngram_range=ngram_range)
            pipe = Pipeline([
                ('vec', vec),
                ('clf', clf)
            ])
            gs = GridSearchCV(pipe, param_grid=grid, cv=5, scoring='f1_macro', n_jobs=-1)
            gs.fit(X_train, y_train)

            y_pred = gs.best_estimator_.predict(X_test)
            acc = accuracy_score(y_test, y_pred)
            f1 = f1_score(y_test, y_pred, average='macro')

            results.append({
                'Vectorizador': vec_name,
                'N-gramas': ngram_name,
                'Modelo': model_name,
                'Accuracy': round(acc, 4),
                'F1_macro': round(f1, 4),
                'Mejores parámetros': gs.best_params_
            })

            # Mostrar reporte
            print("\nClassification Report:")
            print(classification_report(y_test, y_pred, target_names=["No Estrés", "Estrés"]))
            print("-" * 80)
# Out:
# Probando TF-IDF + unigramas + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.81      0.80      0.81        71
#       Estrés       0.73      0.75      0.74        51
#
#     accuracy                           0.78       122
#    macro avg       0.77      0.77      0.77       122
# weighted avg       0.78      0.78      0.78       122
#
# --------------------------------------------------------------------------------
# Probando TF-IDF + unigramas + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.84      0.80      0.82        71
#       Estrés       0.74      0.78      0.76        51
#
#     accuracy                           0.80       122
#    macro avg       0.79      0.79      0.79       122
# weighted avg       0.80      0.80      0.80       122
#
# --------------------------------------------------------------------------------
# Probando TF-IDF + unigramas + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.87      0.82      0.84        71
#       Estrés       0.76      0.82      0.79        51
#
#     accuracy                           0.82       122
#    macro avg       0.81      0.82      0.82       122
# weighted avg       0.82      0.82      0.82       122
#
# --------------------------------------------------------------------------------
# Probando TF-IDF + bigramas + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.86      0.77      0.81        71
#       Estrés       0.72      0.82      0.77        51
#
#     accuracy                           0.80       122
#    macro avg       0.79      0.80      0.79       122
# weighted avg       0.80      0.80      0.80       122
#
# --------------------------------------------------------------------------------
# Probando TF-IDF + bigramas + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.86      0.79      0.82        71
#       Estrés       0.74      0.82      0.78        51
#
#     accuracy                           0.80       122
#    macro avg       0.80      0.81      0.80       122
# weighted avg       0.81      0.80      0.80       122
#
# --------------------------------------------------------------------------------
# Probando TF-IDF + bigramas + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.85      0.82      0.83        71
#       Estrés       0.76      0.80      0.78        51
#
#     accuracy                           0.81       122
#    macro avg       0.81      0.81      0.81       122
# weighted avg       0.81      0.81      0.81       122
#
# --------------------------------------------------------------------------------
# Probando TF-IDF + trigramas + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.63      0.89      0.74        71
#       Estrés       0.64      0.27      0.38        51
#
#     accuracy                           0.63       122
#    macro avg       0.63      0.58      0.56       122
# weighted avg       0.63      0.63      0.59       122
#
# --------------------------------------------------------------------------------
# Probando TF-IDF + trigramas + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.62      0.89      0.73        71
#       Estrés       0.62      0.25      0.36        51
#
#     accuracy                           0.62       122
#    macro avg       0.62      0.57      0.55       122
# weighted avg       0.62      0.62      0.58       122
#
# --------------------------------------------------------------------------------
# Probando TF-IDF + trigramas + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.62      0.89      0.73        71
#       Estrés       0.62      0.25      0.36        51
#
#     accuracy                           0.62       122
#    macro avg       0.62      0.57      0.55       122
# weighted avg       0.62      0.62      0.58       122
#
# --------------------------------------------------------------------------------
# Probando TF-IDF + uni+bi + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.85      0.79      0.82        71
#       Estrés       0.73      0.80      0.77        51
#
#     accuracy                           0.80       122
#    macro avg       0.79      0.80      0.79       122
# weighted avg       0.80      0.80      0.80       122
#
# --------------------------------------------------------------------------------
# Probando TF-IDF + uni+bi + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.90      0.76      0.82        71
#       Estrés       0.73      0.88      0.80        51
#
#     accuracy                           0.81       122
#    macro avg       0.81      0.82      0.81       122
# weighted avg       0.83      0.81      0.81       122
#
# --------------------------------------------------------------------------------
# Probando TF-IDF + uni+bi + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.91      0.75      0.82        71
#       Estrés       0.72      0.90      0.80        51
#
#     accuracy                           0.81       122
#    macro avg       0.82      0.82      0.81       122
# weighted avg       0.83      0.81      0.81       122
#
# --------------------------------------------------------------------------------
# Probando TF-IDF + uni+tri + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.89      0.76      0.82        71
#       Estrés       0.72      0.86      0.79        51
#
#     accuracy                           0.80       122
#    macro avg       0.80      0.81      0.80       122
# weighted avg       0.82      0.80      0.80       122
#
# --------------------------------------------------------------------------------
# Probando TF-IDF + uni+tri + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.91      0.75      0.82        71
#       Estrés       0.72      0.90      0.80        51
#
#     accuracy                           0.81       122
#    macro avg       0.82      0.82      0.81       122
# weighted avg       0.83      0.81      0.81       122
#
# --------------------------------------------------------------------------------
# Probando TF-IDF + uni+tri + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.90      0.75      0.82        71
#       Estrés       0.71      0.88      0.79        51
#
#     accuracy                           0.80       122
#    macro avg       0.81      0.81      0.80       122
# weighted avg       0.82      0.80      0.80       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + unigramas + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.88      0.73      0.80        71
#       Estrés       0.70      0.86      0.77        51
#
#     accuracy                           0.79       122
#    macro avg       0.79      0.80      0.79       122
# weighted avg       0.80      0.79      0.79       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + unigramas + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.87      0.87      0.87        71
#       Estrés       0.82      0.82      0.82        51
#
#     accuracy                           0.85       122
#    macro avg       0.85      0.85      0.85       122
# weighted avg       0.85      0.85      0.85       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + unigramas + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.88      0.85      0.86        71
#       Estrés       0.80      0.84      0.82        51
#
#     accuracy                           0.84       122
#    macro avg       0.84      0.84      0.84       122
# weighted avg       0.85      0.84      0.84       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + bigramas + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.88      0.80      0.84        71
#       Estrés       0.75      0.84      0.80        51
#
#     accuracy                           0.82       122
#    macro avg       0.82      0.82      0.82       122
# weighted avg       0.83      0.82      0.82       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + bigramas + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.78      0.82      0.80        71
#       Estrés       0.73      0.69      0.71        51
#
#     accuracy                           0.76       122
#    macro avg       0.76      0.75      0.75       122
# weighted avg       0.76      0.76      0.76       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + bigramas + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.76      0.86      0.81        71
#       Estrés       0.76      0.63      0.69        51
#
#     accuracy                           0.76       122
#    macro avg       0.76      0.74      0.75       122
# weighted avg       0.76      0.76      0.76       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + trigramas + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.63      0.87      0.73        71
#       Estrés       0.61      0.27      0.38        51
#
#     accuracy                           0.62       122
#    macro avg       0.62      0.57      0.55       122
# weighted avg       0.62      0.62      0.58       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + trigramas + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.59      0.96      0.73        71
#       Estrés       0.50      0.06      0.11        51
#
#     accuracy                           0.58       122
#    macro avg       0.54      0.51      0.42       122
# weighted avg       0.55      0.58      0.47       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + trigramas + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.59      0.96      0.73        71
#       Estrés       0.50      0.06      0.11        51
#
#     accuracy                           0.58       122
#    macro avg       0.54      0.51      0.42       122
# weighted avg       0.55      0.58      0.47       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + uni+bi + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.93      0.73      0.82        71
#       Estrés       0.71      0.92      0.80        51
#
#     accuracy                           0.81       122
#    macro avg       0.82      0.83      0.81       122
# weighted avg       0.84      0.81      0.81       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + uni+bi + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.88      0.79      0.83        71
#       Estrés       0.74      0.84      0.79        51
#
#     accuracy                           0.81       122
#    macro avg       0.81      0.82      0.81       122
# weighted avg       0.82      0.81      0.81       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + uni+bi + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.89      0.80      0.84        71
#       Estrés       0.76      0.86      0.81        51
#
#     accuracy                           0.83       122
#    macro avg       0.82      0.83      0.83       122
# weighted avg       0.84      0.83      0.83       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + uni+tri + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.93      0.73      0.82        71
#       Estrés       0.71      0.92      0.80        51
#
#     accuracy                           0.81       122
#    macro avg       0.82      0.83      0.81       122
# weighted avg       0.84      0.81      0.81       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + uni+tri + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.88      0.79      0.83        71
#       Estrés       0.74      0.84      0.79        51
#
#     accuracy                           0.81       122
#    macro avg       0.81      0.82      0.81       122
# weighted avg       0.82      0.81      0.81       122
#
# --------------------------------------------------------------------------------
# Probando Frecuencia + uni+tri + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.86      0.79      0.82        71
#       Estrés       0.74      0.82      0.78        51
#
#     accuracy                           0.80       122
#    macro avg       0.80      0.81      0.80       122
# weighted avg       0.81      0.80      0.80       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + unigramas + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.91      0.73      0.81        71
#       Estrés       0.71      0.90      0.79        51
#
#     accuracy                           0.80       122
#    macro avg       0.81      0.82      0.80       122
# weighted avg       0.83      0.80      0.80       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + unigramas + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.89      0.80      0.84        71
#       Estrés       0.76      0.86      0.81        51
#
#     accuracy                           0.83       122
#    macro avg       0.82      0.83      0.83       122
# weighted avg       0.84      0.83      0.83       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + unigramas + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.87      0.85      0.86        71
#       Estrés       0.79      0.82      0.81        51
#
#     accuracy                           0.84       122
#    macro avg       0.83      0.83      0.83       122
# weighted avg       0.84      0.84      0.84       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + bigramas + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.88      0.80      0.84        71
#       Estrés       0.75      0.84      0.80        51
#
#     accuracy                           0.82       122
#    macro avg       0.82      0.82      0.82       122
# weighted avg       0.83      0.82      0.82       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + bigramas + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.78      0.80      0.79        71
#       Estrés       0.71      0.69      0.70        51
#
#     accuracy                           0.75       122
#    macro avg       0.75      0.74      0.75       122
# weighted avg       0.75      0.75      0.75       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + bigramas + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.77      0.86      0.81        71
#       Estrés       0.77      0.65      0.70        51
#
#     accuracy                           0.77       122
#    macro avg       0.77      0.75      0.76       122
# weighted avg       0.77      0.77      0.77       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + trigramas + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.63      0.87      0.73        71
#       Estrés       0.61      0.27      0.38        51
#
#     accuracy                           0.62       122
#    macro avg       0.62      0.57      0.55       122
# weighted avg       0.62      0.62      0.58       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + trigramas + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.59      0.96      0.73        71
#       Estrés       0.50      0.06      0.11        51
#
#     accuracy                           0.58       122
#    macro avg       0.54      0.51      0.42       122
# weighted avg       0.55      0.58      0.47       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + trigramas + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.59      0.96      0.73        71
#       Estrés       0.50      0.06      0.11        51
#
#     accuracy                           0.58       122
#    macro avg       0.54      0.51      0.42       122
# weighted avg       0.55      0.58      0.47       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + uni+bi + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.93      0.75      0.83        71
#       Estrés       0.72      0.92      0.81        51
#
#     accuracy                           0.82       122
#    macro avg       0.83      0.83      0.82       122
# weighted avg       0.84      0.82      0.82       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + uni+bi + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.89      0.80      0.84        71
#       Estrés       0.76      0.86      0.81        51
#
#     accuracy                           0.83       122
#    macro avg       0.82      0.83      0.83       122
# weighted avg       0.84      0.83      0.83       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + uni+bi + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.89      0.82      0.85        71
#       Estrés       0.77      0.86      0.81        51
#
#     accuracy                           0.84       122
#    macro avg       0.83      0.84      0.83       122
# weighted avg       0.84      0.84      0.84       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + uni+tri + NaiveBayes
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.93      0.75      0.83        71
#       Estrés       0.72      0.92      0.81        51
#
#     accuracy                           0.82       122
#    macro avg       0.83      0.83      0.82       122
# weighted avg       0.84      0.82      0.82       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + uni+tri + SVM
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.89      0.80      0.84        71
#       Estrés       0.76      0.86      0.81        51
#
#     accuracy                           0.83       122
#    macro avg       0.82      0.83      0.83       122
# weighted avg       0.84      0.83      0.83       122
#
# --------------------------------------------------------------------------------
# Probando Binaria + uni+tri + LogisticRegression
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    No Estrés       0.88      0.80      0.84        71
#       Estrés       0.75      0.84      0.80        51
#
#     accuracy                           0.82       122
#    macro avg       0.82      0.82      0.82       122
# weighted avg       0.83      0.82      0.82       122
#
# --------------------------------------------------------------------------------

# %%
results_df = pd.DataFrame(results)
results_df = results_df.sort_values(by='F1_macro', ascending=False)
results_df.reset_index(drop=True, inplace=True)
results_df.head(20)  # Muestra los 10 mejores
# Out:
#    Vectorizador   N-gramas              Modelo  Accuracy  F1_macro  \
# 0    Frecuencia  unigramas                 SVM    0.8525    0.8484
# 1    Frecuencia  unigramas  LogisticRegression    0.8443    0.8412
# 2       Binaria     uni+bi  LogisticRegression    0.8361    0.8339
# 3       Binaria  unigramas  LogisticRegression    0.8361    0.8324
# 4       Binaria  unigramas                 SVM    0.8279    0.8259
# 5       Binaria    uni+tri                 SVM    0.8279    0.8259
# 6    Frecuencia     uni+bi  LogisticRegression    0.8279    0.8259
# 7       Binaria     uni+bi                 SVM    0.8279    0.8259
# 8       Binaria     uni+bi          NaiveBayes    0.8197    0.8192
# 9       Binaria    uni+tri          NaiveBayes    0.8197    0.8192
# 10      Binaria   bigramas          NaiveBayes    0.8197    0.8173
# 11   Frecuencia   bigramas          NaiveBayes    0.8197    0.8173
# 12      Binaria    uni+tri  LogisticRegression    0.8197    0.8173
# 13       TF-IDF  unigramas  LogisticRegression    0.8197    0.8165
# 14   Frecuencia     uni+bi          NaiveBayes    0.8115    0.8112
# 15   Frecuencia    uni+tri          NaiveBayes    0.8115    0.8112
# 16       TF-IDF     uni+bi  LogisticRegression    0.8115    0.8109
# 17       TF-IDF    uni+tri                 SVM    0.8115    0.8109
# 18       TF-IDF     uni+bi                 SVM    0.8115    0.8104
# 19   Frecuencia     uni+bi                 SVM    0.8115    0.8093
#
#                                    Mejores parámetros
# 0   {'clf__C': 1, 'clf__gamma': 'scale', 'clf__ker...
# 1                {'clf__C': 10, 'clf__penalty': 'l2'}
# 2                {'clf__C': 10, 'clf__penalty': 'l2'}
# 3                {'clf__C': 10, 'clf__penalty': 'l2'}
# 4   {'clf__C': 0.1, 'clf__gamma': 'scale', 'clf__k...
# 5   {'clf__C': 0.1, 'clf__gamma': 'scale', 'clf__k...
# 6                {'clf__C': 10, 'clf__penalty': 'l2'}
# 7   {'clf__C': 0.1, 'clf__gamma': 'scale', 'clf__k...
# 8                                 {'clf__alpha': 0.1}
# 9                                 {'clf__alpha': 0.1}
# 10                                {'clf__alpha': 1.0}
# 11                                {'clf__alpha': 1.0}
# 12               {'clf__C': 10, 'clf__penalty': 'l2'}
# 13               {'clf__C': 10, 'clf__penalty': 'l2'}
# 14                                {'clf__alpha': 1.0}
# 15                                {'clf__alpha': 1.0}
# 16               {'clf__C': 10, 'clf__penalty': 'l2'}
# 17  {'clf__C': 10, 'clf__gamma': 'scale', 'clf__ke...
# 18  {'clf__C': 10, 'clf__gamma': 'scale', 'clf__ke...
# 19  {'clf__C': 0.1, 'clf__gamma': 'scale', 'clf__k...

# %%
results_df.to_csv("/content/resultados_experimentos.csv", index=False)
